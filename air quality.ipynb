# %%
#data exploration(describe , info, head and tail, unique)
#check the type of data
#data cleaning(isna, fillna)
#dropping irrelevant columns as well as duplicate values and renaming them
#detecting outliers
#plot different graphs

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\amish\\Downloads\\Air_Quality.csv")  #loading the data into dataframe

# %%
df
# Out:
#        Unique ID  Indicator ID                    Name Measure Measure Info  \
# 0         336867           375  Nitrogen dioxide (NO2)    Mean          ppb
# 1         336741           375  Nitrogen dioxide (NO2)    Mean          ppb
# 2         550157           375  Nitrogen dioxide (NO2)    Mean          ppb
# 3         412802           375  Nitrogen dioxide (NO2)    Mean          ppb
# 4         412803           375  Nitrogen dioxide (NO2)    Mean          ppb
# ...          ...           ...                     ...     ...          ...
# 18857     165993           375  Nitrogen dioxide (NO2)    Mean          ppb
# 18858     338255           386              Ozone (O3)    Mean          ppb
# 18859     651029           386              Ozone (O3)    Mean          ppb
# 18860     667628           375  Nitrogen dioxide (NO2)    Mean          ppb
# 18861     167586           375  Nitrogen dioxide (NO2)    Mean          ppb
#
# ...

# %%
#data exploration
df.describe()
# Out:
#            Unique ID  Indicator ID   Geo Join ID    Data Value  Message
# count   18862.000000  18862.000000  1.886200e+04  18862.000000      0.0
# mean   452004.167533    431.817888  5.983262e+05     21.051580      NaN
# std    262910.731230    113.946565  7.819721e+06     23.564920      NaN
# min    130355.000000    365.000000  1.000000e+00      0.000000      NaN
# 25%    176073.250000    365.000000  2.020000e+02      8.742004      NaN
# 50%    412490.500000    375.000000  3.030000e+02     14.790000      NaN
# 75%    669588.750000    386.000000  4.040000e+02     26.267500      NaN
# max    878254.000000    661.000000  1.051061e+08    424.700000      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18862 entries, 0 to 18861
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unique ID       18862 non-null  int64
#  1   Indicator ID    18862 non-null  int64
#  2   Name            18862 non-null  object
#  3   Measure         18862 non-null  object
#  4   Measure Info    18862 non-null  object
#  5   Geo Type Name   18862 non-null  object
#  6   Geo Join ID     18862 non-null  int64
#  7   Geo Place Name  18862 non-null  object
#  8   Time Period     18862 non-null  object
#  9   Start_Date      18862 non-null  object
#  10  Data Value      18862 non-null  float64
#  11  Message         0 non-null      float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 1.7+ MB

# %%
df.head()
# Out:
#    Unique ID  Indicator ID                    Name Measure Measure Info  \
# 0     336867           375  Nitrogen dioxide (NO2)    Mean          ppb
# 1     336741           375  Nitrogen dioxide (NO2)    Mean          ppb
# 2     550157           375  Nitrogen dioxide (NO2)    Mean          ppb
# 3     412802           375  Nitrogen dioxide (NO2)    Mean          ppb
# 4     412803           375  Nitrogen dioxide (NO2)    Mean          ppb
#
#   Geo Type Name  Geo Join ID                     Geo Place Name  \
# 0            CD          407      Flushing and Whitestone (CD7)
# 1            CD          107              Upper West Side (CD7)
# 2            CD          414  Rockaway and Broad Channel (CD14)
# 3            CD          407      Flushing and Whitestone (CD7)
# 4            CD          407      Flushing and Whitestone (CD7)
#
#            Time Period  Start_Date  Data Value  Message
# 0       Winter 2014-15  12/01/2014       23.97      NaN
# ...

# %%
df.tail()
# Out:
#        Unique ID  Indicator ID                    Name Measure Measure Info  \
# 18857     165993           375  Nitrogen dioxide (NO2)    Mean          ppb
# 18858     338255           386              Ozone (O3)    Mean          ppb
# 18859     651029           386              Ozone (O3)    Mean          ppb
# 18860     667628           375  Nitrogen dioxide (NO2)    Mean          ppb
# 18861     167586           375  Nitrogen dioxide (NO2)    Mean          ppb
#
#       Geo Type Name  Geo Join ID                         Geo Place Name  \
# 18857            CD          207  Kingsbridge Heights and Bedford (CD7)
# 18858            CD          107                  Upper West Side (CD7)
# 18859            CD          307                      Sunset Park (CD7)
# 18860            CD          207  Kingsbridge Heights and Bedford (CD7)
# 18861            CD          207  Kingsbridge Heights and Bedford (CD7)
#
#                Time Period  Start_Date  Data Value  Message
# ...

# %%
df.shape
# Out:
# (18862, 12)

# %%
df.columns
# Out:
# Index(['Unique ID', 'Indicator ID', 'Name', 'Measure', 'Measure Info',
#        'Geo Type Name', 'Geo Join ID', 'Geo Place Name', 'Time Period',
#        'Start_Date', 'Data Value', 'Message'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unique ID           int64
# Indicator ID        int64
# Name               object
# Measure            object
# Measure Info       object
# Geo Type Name      object
# Geo Join ID         int64
# Geo Place Name     object
# Time Period        object
# Start_Date         object
# Data Value        float64
# Message           float64
# dtype: object

# %%
data=df[['Unique ID','Indicator ID','Geo Join ID','Data Value']]
data
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Data Value'],y=df['Name'],color='y')
# Out:
# <Axes: xlabel='Data Value', ylabel='Name'>

# %%
# Visualize the distribution of Data Value
plt.figure(figsize=(10, 6))
sns.histplot(df['Data Value'], bins=30, kde=True,color='pink')
plt.grid(True,color='y',linestyle=':')
plt.title('Distribution of Data Value')
plt.xlabel('Data Value')
plt.ylabel('Frequency')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,6))
ax.scatter(df['Data Value'], df['Indicator ID'],color='red')
ax.set_xlabel('Data Value')
ax.set_ylabel('Indicator ID')
plt.show()

# %%
#data cleaning
#dropping the missing or null values
print(df.isnull().sum())  #no null values, if there would be null values then df = df.dropna()
# Out:
# Unique ID             0
# Indicator ID          0
# Name                  0
# Measure               0
# Measure Info          0
# Geo Type Name         0
# Geo Join ID           0
# Geo Place Name        0
# Time Period           0
# Start_Date            0
# Data Value            0
# Message           18862
# dtype: int64

# %%
df = df.drop(['Indicator ID','Measure', 'Measure Info',
       'Geo Type Name', 'Geo Join ID','Message'], axis=1)              #dropping irrelevant columns

# %%
df.head()
# Out:
#    Unique ID                    Name                     Geo Place Name  \
# 0     336867  Nitrogen dioxide (NO2)      Flushing and Whitestone (CD7)
# 1     336741  Nitrogen dioxide (NO2)              Upper West Side (CD7)
# 2     550157  Nitrogen dioxide (NO2)  Rockaway and Broad Channel (CD14)
# 3     412802  Nitrogen dioxide (NO2)      Flushing and Whitestone (CD7)
# 4     412803  Nitrogen dioxide (NO2)      Flushing and Whitestone (CD7)
#
#            Time Period  Start_Date  Data Value
# 0       Winter 2014-15  12/01/2014       23.97
# 1       Winter 2014-15  12/01/2014       27.42
# 2  Annual Average 2017  01/01/2017       12.55
# 3       Winter 2015-16  12/01/2015       22.63
# 4          Summer 2016  06/01/2016       14.00

# %%
df.shape
# Out:
# (18862, 6)

# %%
#renaming the columns
df = df.rename(columns={"Name":"Element","Time Period":"Time","Data Value":"Values"})

# %%
df.columns
# Out:
# Index(['Unique ID', 'Element', 'Geo Place Name', 'Time', 'Start_Date',
#        'Values'],
#       dtype='object')

# %%
df.tail()
# Out:
#        Unique ID                 Element  \
# 18857     165993  Nitrogen dioxide (NO2)
# 18858     338255              Ozone (O3)
# 18859     651029              Ozone (O3)
# 18860     667628  Nitrogen dioxide (NO2)
# 18861     167586  Nitrogen dioxide (NO2)
#
#                               Geo Place Name                 Time  Start_Date  \
# 18857  Kingsbridge Heights and Bedford (CD7)       Winter 2012-13  12/01/2012
# 18858                  Upper West Side (CD7)          Summer 2015  06/01/2015
# 18859                      Sunset Park (CD7)          Summer 2019  06/01/2019
# 18860  Kingsbridge Heights and Bedford (CD7)       Winter 2019-20  12/01/2019
# 18861  Kingsbridge Heights and Bedford (CD7)  Annual Average 2010  12/01/2009
#
#        Values
# 18857   25.78
# 18858   28.13
# 18859   28.78
# 18860   23.68
# 18861   23.77

# %%
#dropping the duplicate values 
duplicatevalues = df[df.duplicated()]
print("number of duplicate rows: ", duplicatevalues.shape)  #it will give number of duplicate rows
# Out:
# number of duplicate rows:  (0, 6)

# %%
df.count()
# Out:
# Unique ID         18862
# Element           18862
# Geo Place Name    18862
# Time              18862
# Start_Date        18862
# Values            18862
# dtype: int64

# %%
df = df.drop_duplicates()  #no duplicate rows found
df.head(5)
# Out:
#    Unique ID                 Element                     Geo Place Name  \
# 0     336867  Nitrogen dioxide (NO2)      Flushing and Whitestone (CD7)
# 1     336741  Nitrogen dioxide (NO2)              Upper West Side (CD7)
# 2     550157  Nitrogen dioxide (NO2)  Rockaway and Broad Channel (CD14)
# 3     412802  Nitrogen dioxide (NO2)      Flushing and Whitestone (CD7)
# 4     412803  Nitrogen dioxide (NO2)      Flushing and Whitestone (CD7)
#
#                   Time  Start_Date  Values
# 0       Winter 2014-15  12/01/2014   23.97
# 1       Winter 2014-15  12/01/2014   27.42
# 2  Annual Average 2017  01/01/2017   12.55
# 3       Winter 2015-16  12/01/2015   22.63
# 4          Summer 2016  06/01/2016   14.00

# %%
df['Element'].unique()
# Out:
# array(['Nitrogen dioxide (NO2)', 'Fine particles (PM 2.5)',
#        'Boiler Emissions- Total SO2 Emissions', 'Ozone (O3)',
#        'Asthma emergency department visits due to PM2.5',
#        'Annual vehicle miles traveled',
#        'Respiratory hospitalizations due to PM2.5 (age 20+)',
#        'Asthma hospitalizations due to Ozone',
#        'Boiler Emissions- Total NOx Emissions',
#        'Boiler Emissions- Total PM2.5 Emissions',
#        'Outdoor Air Toxics - Formaldehyde',
#        'Outdoor Air Toxics - Benzene',
#        'Asthma emergency departments visits due to Ozone',
#        'Annual vehicle miles traveled (cars)',
#        'Annual vehicle miles traveled (trucks)',
#        'Cardiovascular hospitalizations due to PM2.5 (age 40+)',
#        'Deaths due to PM2.5',
#        'Cardiac and respiratory deaths due to Ozone'], dtype=object)

# %%
df.count()
# Out:
# Unique ID         18862
# Element           18862
# Geo Place Name    18862
# Time              18862
# Start_Date        18862
# Values            18862
# dtype: int64

# %%
#detecting outliers
plt.figure(figsize=(16,10))
sns.boxplot(x=df['Values'],y=df['Element'],color='g')
# Out:
# <Axes: xlabel='Values', ylabel='Element'>

# %%
plt.figure(figsize=(10,10))
sns.boxplot(y=df['Start_Date'],color='purple')
# Out:
# <Axes: ylabel='Start_Date'>

# %%
plt.figure(figsize=(10,10))
sns.boxplot(y=df['Values'])
# Out:
# <Axes: ylabel='Values'>

# %%
df['Time'].unique() #unique values
# Out:
# array(['Winter 2014-15', 'Annual Average 2017', 'Winter 2015-16',
#        'Summer 2016', 'Annual Average 2018', 'Annual Average 2016',
#        'Winter 2021-22', 'Annual Average 2021', 'Summer 2009',
#        'Winter 2010-11', 'Annual Average 2013', 'Summer 2021',
#        'Winter 2020-21', 'Summer 2010', 'Summer 2011', 'Summer 2012',
#        'Summer 2013', 'Winter 2013-14', 'Annual Average 2019',
#        'Winter 2017-18', 'Annual Average 2022', 'Winter 2008-09',
#        'Summer 2019', 'Summer 2015', 'Winter 2019-20',
#        'Annual Average 2023', 'Winter 2022-23', 'Winter 2012-13',
#        'Annual Average 2010', 'Annual Average 2012', 'Summer 2022',
#        'Annual Average 2014', 'Summer 2020', '2015',
#        'Annual Average 2015', 'Summer 2014', 'Winter 2018-19', '2013',
#        'Winter 2011-12', 'Summer 2017', 'Summer 2018', 'Summer 2023',
#        'Winter 2016-17', 'Winter 2009-10', 'Annual Average 2009',
# ...

# %%
sns.boxplot(df)
plt.grid(True)

# %%
data1=df['Unique ID']   #finding outlier by iris
data1
q1 = np.percentile(data1,25)
print(q1)
# Out:
# 176073.25

# %%
q3 = np.percentile(data1,75)
print(q3)
# Out:
# 669588.75

# %%
iqr = q3-q1
print(iqr)
# Out:
# 493515.5

# %%
ub=q3+(1.5*iqr)
print(ub)
lb = q1=(1.5*iqr)
print(lb)
outliers = data1[(data1 < lb) | (data1 > ub)]
print(outliers)
# Out:
# 1409862.0
# 740273.25
# 0        336867
# 1        336741
# 2        550157
# 3        412802
# 4        412803
#           ...
# 18857    165993
# 18858    338255
# 18859    651029
# 18860    667628
# 18861    167586
# Name: Unique ID, Length: 14683, dtype: int64

# %%
#finding outlier by zscore
data2 = df['Unique ID']
data2
mean=np.mean(data2)
print("Mean Of Data",mean)
std=np.std(data2)
print("Print STD Of Data",std)
z_score=(data2-mean)/std
print(z_score)
print(z_score.head(16))
outliers=data2[(z_score < -3) | (z_score > 3)]
print("Printing Outliers",outliers)
print(data2.head(16))
# Out:
# Mean Of Data 452004.16753260524
# Print STD Of Data 262903.76181458886
# 0       -0.437944
# 1       -0.438423
# 2        0.373341
# 3       -0.149112
# 4       -0.149108
#            ...
# 18857   -1.087893
# 18858   -0.432665
# 18859    0.757025
# 18860    0.820163
# 18861   -1.081834
# Name: Unique ID, Length: 18862, dtype: float64
# 0    -0.437944
# 1    -0.438423
# 2     0.373341
# 3    -0.149112
# 4    -0.149108
# 5    -0.149591
# 6    -0.149588
# 7     0.574506
# 8    -0.149105
# 9     1.421919
# 10    1.100353
# 11   -1.085284
# 12   -1.088201
# 13   -1.081020
# 14   -0.437864
# 15    1.100349
# Name: Unique ID, dtype: float64
# Printing Outliers Series([], Name: Unique ID, dtype: int64)
# 0     336867
# 1     336741
# 2     550157
# 3     412802
# 4     412803
# 5     412676
# 6     412677
# 7     603044
# 8     412804
# 9     825832
# 10    741291
# 11    166679
# 12    165912
# 13    167800
# 14    336888
# 15    741290
# Name: Unique ID, dtype: int64

# %%
df = df.drop(outliers.index)  #drop rows containing outliers
outliers=data2[(z_score < -3) | (z_score > 3)]
print("Printing Outliers",outliers)
print(data2.head(16))
# Out:
# Printing Outliers Series([], Name: Unique ID, dtype: int64)
# 0     336867
# 1     336741
# 2     550157
# 3     412802
# 4     412803
# 5     412676
# 6     412677
# 7     603044
# 8     412804
# 9     825832
# 10    741291
# 11    166679
# 12    165912
# 13    167800
# 14    336888
# 15    741290
# Name: Unique ID, dtype: int64
